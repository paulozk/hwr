# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from recognize_handwriting import *
# Out:
# Using TensorFlow backend.

# %%
path = 'image-data/test19.jpg'
image = cv2.imread(path, cv2.IMREAD_GRAYSCALE)
plt.figure(figsize = (500,10))
plt.imshow(image, cmap='gray', aspect = 1)
plt.show()

# %%
recognize_handwriting(image, path, plot = True)
# Out:
# Average word height and width: 46.75609756097561 48.853658536585364
# [302.6832826893371, 5]
# [396.318250756607, 8]
# [493.17810320260526, 10]
# [592.8281150630826, 8]
# [692.9997894172499, 7]
# [793.5702176033146, 7]
# [889.809769137882, 5]
# [982.0532900447353, 2]
# [-100, 1]
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 300)               399600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 300)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 27)                8127
# =================================================================
# Total params: 407,727
# Trainable params: 407,727
# Non-trainable params: 0
# _________________________________________________________________
# LSTM model: None
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9990513
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.9938793
# Best character: waw
# Predicted sequence: ['kaf', 'waw'] [0.9990513, 0.9938793]
# -----LSTM:-------
# N chars: 2
# orig shape: (53, 66)
# Idx: [ 2 24]
# Idx: [7]
# Idx: [24]
# Word preds: ['bet', 'waw']
# Word probs: [0.4110100269317627, 0.7861539125442505]
# ch preds: ['kaf', 'waw']
# ch probs: [0.9835844039916992, 0.9998170733451843]
# Final output: ['kaf', 'waw']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.99995697
# Best character: yod
# Component:
# Recognizing the following character:
# Best score: 0.6936836
# Best character: he
# Component:
# Recognizing the following character:
# Best score: 0.9975387
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.79299945
# Best character: he
# Predicted sequence: ['yod', 'he', 'nun-final', 'he'] [0.99995697, 0.6936836, 0.9975387, 0.79299945]
# -----LSTM:-------
# N chars: 4
# orig shape: (61, 136)
# Idx: [ 3  5  6 17]
# Idx: [25]
# Idx: [5]
# Idx: [24]
# Idx: [5]
# Word preds: ['dalet', 'he', 'het', 'resh']
# Word probs: [0.0588558204472065, 0.7311103343963623, 0.9978979825973511, 0.9992892742156982]
# ch preds: ['yod', 'he', 'waw', 'he']
# ch probs: [0.5924662351608276, 0.9924348592758179, 0.9939561486244202, 0.9988701939582825]
# Empty position: 0
# LSTM:  yod 0.5924662351608276
# CNN:  yod 0.99995697
# Empty position: 2
# LSTM:  waw 0.9939561486244202
# CNN:  nun-final 0
# Final output: ['yod', 'he', 'waw', 'he']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.7724192
# Best character: het
# Predicted sequence: ['het'] [0.7724192]
# -----LSTM:-------
# N chars: 1
# orig shape: (53, 68)
# Idx: [10]
# Idx: [6]
# Word preds: ['mem']
# Word probs: [0.32459893822669983]
# ch preds: ['het']
# ch probs: [0.24634137749671936]
# Empty position: 0
# LSTM:  het 0.24634137749671936
# CNN:  het 0.7724192
# Final output: ['het']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.83341163
# Best character: nun-final
# Predicted sequence: ['nun-final'] [0.83341163]
# -----LSTM:-------
# N chars: 1
# orig shape: (50, 46)
# Idx: [14]
# Idx: [1]
# Word preds: ['pe']
# Word probs: [0.29038211703300476]
# ch preds: ['ayin']
# ch probs: [0.9380247592926025]
# Empty position: 0
# LSTM:  ayin 0.9380247592926025
# CNN:  nun-final 0.83341163
# Final output: ['ayin']
# test7
# ch: kaf
# code: 1499
# chr: כ
# ch: waw
# code: 1493
# chr: ו
# ch: yod
# code: 1497
# chr: י
# ch: he
# code: 1492
# chr: ה
# ch: waw
# code: 1493
# chr: ו
# ch: he
# code: 1492
# chr: ה
# ch: het
# code: 1495
# chr: ח
# ch: ayin
# code: 1506
# chr: ע
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9999832
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.88845736
# Best character: waw
# Component:
# Recognizing the following character:
# Best score: 0.99807954
# Best character: resh
# Predicted sequence: ['nun-medial', 'waw', 'resh'] [0.9999832, 0.88845736, 0.99807954]
# -----LSTM:-------
# N chars: 3
# orig shape: (56, 115)
# Idx: [4 8 9]
# Idx: [13]
# Idx: [24]
# Idx: [17]
# Word preds: ['gimel', 'kaf-final', 'lamed']
# Word probs: [0.17888286709785461, 0.3773515224456787, 0.9523124694824219]
# ch preds: ['nun-medial', 'waw', 'resh']
# ch probs: [0, 0.828470766544342, 0.6148893237113953]
# Empty position: 0
# LSTM:  nun-medial 0
# CNN:  nun-medial 0
# Empty position: 1
# LSTM:  waw 0.828470766544342
# CNN:  waw 0.88845736
# Final output: ['kaf-final', 'waw', 'resh']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.83313584
# Best character: waw
# Component:
# Recognizing the following character:
# Best score: 0.9748687
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.7583254
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.99966085
# Best character: dalet
# Component:
# Recognizing the following character:
# Best score: 0.56779397
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.9992204
# Best character: nun-final
# Predicted sequence: ['waw', 'nun-medial', 'kaf', 'dalet', 'nun-final', 'nun-final'] [0.83313584, 0.9748687, 0.7583254, 0.99966085, 0.56779397, 0.9992204]
# -----LSTM:-------
# N chars: 6
# orig shape: (71, 161)
# Idx: [ 2  3  4  7  9 17]
# Idx: [17]
# Idx: [2]
# Idx: [14]
# Idx: [17]
# Idx: [2]
# Idx: [2]
# Word preds: ['bet', 'dalet', 'gimel', 'kaf', 'lamed', 'resh']
# Word probs: [0.0031054753344506025, 0.024744698777794838, 0.4749974012374878, 0.882056713104248, 0.9156391620635986, 0.9733065366744995]
# ch preds: ['resh', 'bet', 'pe', 'resh', 'bet', 'bet']
# ch probs: [0.5088946223258972, 0.9901753067970276, 0.7491072416305542, 0.3463899493217468, 0.9936218857765198, 0.26792189478874207]
# Final output: ['resh', 'bet', 'kaf', 'dalet', 'bet', 'nun-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9687433
# Best character: alef
# Component:
# Recognizing the following character:
# Best score: 0.9949185
# Best character: tet
# Component:
# Recognizing the following character:
# Best score: 0.9935003
# Best character: dalet
# Predicted sequence: ['alef', 'tet', 'dalet'] [0.9687433, 0.9949185, 0.9935003]
# -----LSTM:-------
# N chars: 3
# orig shape: (60, 139)
# Idx: [ 0 15 17]
# Idx: [0]
# Idx: [19]
# Idx: [17]
# Word preds: ['alef', 'pe-final', 'resh']
# Word probs: [0.10789167881011963, 0.907457709312439, 0.9600238800048828]
# ch preds: ['alef', 'shin', 'resh']
# ch probs: [0.9998263716697693, 0.9999409914016724, 0.5941848158836365]
# Empty position: 1
# LSTM:  shin 0.9999409914016724
# CNN:  tet 0.9949185
# Final output: ['alef', 'shin', 'resh']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9573966
# Best character: dalet
# Component:
# (48, 35)
# Recognizing the following character:
# Best score: 0.665102
# Best character: dalet
# (48, 38)
# Recognizing the following character:
# Best score: 0.57123816
# Best character: bet
# Predicted sequence: ['dalet', 'bet', 'dalet'] [0.9573966, 0.57123816, 0.665102]
# -----LSTM:-------
# N chars: 3
# orig shape: (55, 118)
# Idx: [ 2  3 17]
# Idx: [17]
# Idx: [2]
# Idx: [17]
# Word preds: ['bet', 'dalet', 'resh']
# Word probs: [0.9793774485588074, 0.9984714388847351, 0.9997068047523499]
# ch preds: ['resh', 'bet', 'resh']
# ch probs: [0.426653116941452, 0.9994008541107178, 0.7537665963172913]
# Final output: ['dalet', 'bet', 'resh']
# test7
# ch: kaf-final
# code: 1498
# chr: ך
# ch: waw
# code: 1493
# chr: ו
# ch: resh
# code: 1512
# chr: ר
# ch: resh
# code: 1512
# chr: ר
# ch: bet
# code: 1489
# chr: ב
# ch: kaf
# code: 1499
# chr: כ
# ch: dalet
# code: 1491
# chr: ד
# ch: bet
# code: 1489
# chr: ב
# ch: nun-final
# code: 1503
# chr: ן
# ch: alef
# code: 1488
# chr: א
# ch: shin
# code: 1513
# chr: ש
# ch: resh
# code: 1512
# chr: ר
# ch: dalet
# code: 1491
# chr: ד
# ch: bet
# code: 1489
# chr: ב
# ch: resh
# code: 1512
# chr: ר
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9297185
# Best character: lamed
# Component:
# (51, 43)
# Recognizing the following character:
# Best score: 0.8008092
# Best character: het
# (51, 40)
# Recognizing the following character:
# Best score: 0.97491044
# Best character: taw
# Predicted sequence: ['lamed', 'taw', 'het'] [0.9297185, 0.97491044, 0.8008092]
# -----LSTM:-------
# N chars: 3
# orig shape: (107, 115)
# Idx: [ 1  2 20]
# Idx: [1]
# Idx: [20]
# Idx: [6]
# Word preds: ['ayin', 'bet', 'taw']
# Word probs: [0.044179901480674744, 0.04919616878032684, 0.9280662536621094]
# ch preds: ['ayin', 'taw', 'het']
# ch probs: [0.44749048352241516, 0.6282837986946106, 0.886252224445343]
# Empty position: 0
# LSTM:  ayin 0.44749048352241516
# CNN:  lamed 0.9297185
# Final output: ['lamed', 'taw', 'taw']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9605504
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.98262995
# Best character: nun-final
# Component:
# (75, 32)
# Recognizing the following character:
# Best score: 0.39606062
# Best character: tsadi-medial
# (75, 34)
# Recognizing the following character:
# Best score: 0.9521558
# Best character: bet
# (75, 40)
# Recognizing the following character:
# Best score: 0.5876172
# Best character: alef
# Component:
# Recognizing the following character:
# Best score: 0.8033729
# Best character: he
# Component:
# Recognizing the following character:
# Best score: 0.993755
# Best character: mem
# Predicted sequence: ['nun-final', 'nun-final', 'alef', 'bet', 'tsadi-medial', 'he', 'mem'] [0.9605504, 0.98262995, 0.5876172, 0.9521558, 0.39606062, 0.8033729, 0.993755]
# -----LSTM:-------
# N chars: 7
# orig shape: (115, 238)
# Idx: [ 0  1  2  6  9 13 20]
# Idx: [23]
# Idx: [23]
# Idx: [0]
# Idx: [2]
# Idx: [17]
# Idx: [5]
# Idx: [18]
# Word preds: ['alef', 'ayin', 'bet', 'het', 'lamed', 'nun-medial', 'taw']
# Word probs: [0.13380981981754303, 0.13580653071403503, 0.13857899606227875, 0.19664274156093597, 0.2122880518436432, 0.3670620322227478, 0.4704906940460205]
# ch preds: ['tsadi-medial', 'tsadi-medial', 'alef', 'bet', 'resh', 'he', 'samekh']
# ch probs: [0, 0.6034389138221741, 0.9840571284294128, 0.9467921853065491, 0.6531405448913574, 0.4722980260848999, 0.3233601450920105]
# Empty position: 0
# LSTM:  tsadi-medial 0
# CNN:  nun-final 0
# Empty position: 1
# LSTM:  tsadi-medial 0.6034389138221741
# CNN:  nun-final 0
# Empty position: 4
# LSTM:  resh 0.6531405448913574
# CNN:  tsadi-medial 0.39606062
# Empty position: 6
# LSTM:  samekh 0.3233601450920105
# CNN:  mem 0.993755
# Final output: ['het', 'tsadi-medial', 'alef', 'bet', 'resh', 'he', 'mem']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9858261
# Best character: he
# Component:
# Recognizing the following character:
# Best score: 0.9999914
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.9937884
# Best character: shin
# Component:
# Recognizing the following character:
# Best score: 0.71928555
# Best character: bet
# Component:
# Recognizing the following character:
# Best score: 0.9700824
# Best character: tsadi-medial
# Predicted sequence: ['he', 'nun-medial', 'shin', 'bet', 'tsadi-medial'] [0.9858261, 0.9999914, 0.9937884, 0.71928555, 0.9700824]
# -----LSTM:-------
# N chars: 5
# orig shape: (63, 207)
# Idx: [ 5  6 11 18 19]
# Idx: [5]
# Idx: [2]
# Idx: [19]
# Idx: [2]
# Idx: [1]
# Word preds: ['he', 'het', 'mem-medial', 'samekh', 'shin']
# Word probs: [0.05918954685330391, 0.1436905860900879, 0.16404809057712555, 0.2600306570529938, 0.6326544284820557]
# ch preds: ['he', 'bet', 'shin', 'bet', 'ayin']
# ch probs: [0.9880714416503906, 0.7438459396362305, 0.9999401569366455, 0.98321932554245, 0.9865992069244385]
# Empty position: 4
# LSTM:  ayin 0.9865992069244385
# CNN:  tsadi-medial 0
# Final output: ['he', 'nun-medial', 'shin', 'bet', 'ayin']
# test7
# ch: lamed
# code: 1500
# chr: ל
# ch: taw
# code: 1514
# chr: ת
# ch: taw
# code: 1514
# chr: ת
# ch: het
# code: 1495
# chr: ח
# ch: tsadi-medial
# code: 1510
# chr: צ
# ch: alef
# code: 1488
# chr: א
# ch: bet
# code: 1489
# chr: ב
# ch: resh
# code: 1512
# chr: ר
# ch: he
# code: 1492
# chr: ה
# ch: mem
# code: 1501
# chr: ם
# ch: he
# code: 1492
# chr: ה
# ch: nun-medial
# code: 1504
# chr: נ
# ch: shin
# code: 1513
# chr: ש
# ch: bet
# code: 1489
# chr: ב
# ch: ayin
# code: 1506
# chr: ע
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9999974
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.99709904
# Best character: lamed
# Component:
# Recognizing the following character:
# Best score: 0.99597013
# Best character: nun-final
# Predicted sequence: ['nun-medial', 'lamed', 'nun-final'] [0.9999974, 0.99709904, 0.99597013]
# -----LSTM:-------
# N chars: 3
# orig shape: (96, 128)
# Idx: [ 3 13 24]
# Idx: [2]
# Idx: [13]
# Idx: [24]
# Word preds: ['dalet', 'nun-medial', 'waw']
# Word probs: [0.15177331864833832, 0.3202272653579712, 0.9900651574134827]
# ch preds: ['bet', 'nun-medial', 'waw']
# ch probs: [0.9260361790657043, 0.2601260840892792, 0.9754714965820312]
# Empty position: 0
# LSTM:  bet 0.9260361790657043
# CNN:  nun-medial 0
# Empty position: 1
# LSTM:  nun-medial 0.2601260840892792
# CNN:  lamed 0.99709904
# Final output: ['bet', 'lamed', 'waw']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9999826
# Best character: tet
# Component:
# Recognizing the following character:
# Best score: 0.9994444
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.6358314
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.71975434
# Best character: nun-medial
# Predicted sequence: ['tet', 'nun-final', 'kaf', 'nun-medial'] [0.9999826, 0.9994444, 0.6358314, 0.71975434]
# -----LSTM:-------
# N chars: 4
# orig shape: (77, 156)
# Idx: [ 2  3  5 19]
# Idx: [19]
# Idx: [24]
# Idx: [2]
# Idx: [5]
# Word preds: ['bet', 'dalet', 'he', 'shin']
# Word probs: [0.1312023550271988, 0.2729676365852356, 0.6427199244499207, 0.9755801558494568]
# ch preds: ['shin', 'waw', 'bet', 'he']
# ch probs: [0.9978493452072144, 0.9997541308403015, 0.5280126929283142, 0.8706296682357788]
# Empty position: 1
# LSTM:  waw 0.9997541308403015
# CNN:  nun-final 0
# Final output: ['shin', 'waw', 'bet', 'he']
# Recognizing the following word:
# -----CNN:-------
# Component:
# (73, 29)
# Recognizing the following character:
# Best score: 0.5742447
# Best character: resh
# (73, 35)
# Recognizing the following character:
# Best score: 0.9999938
# Best character: tsadi-medial
# Component:
# Recognizing the following character:
# Best score: 0.5376762
# Best character: nun-final
# Predicted sequence: ['tsadi-medial', 'resh', 'nun-final'] [0.9999938, 0.5742447, 0.5376762]
# -----LSTM:-------
# N chars: 3
# orig shape: (79, 121)
# Idx: [ 0 17 23]
# Idx: [0]
# Idx: [17]
# Idx: [22]
# Word preds: ['alef', 'resh', 'tsadi-medial']
# Word probs: [0.887567400932312, 0.9722906947135925, 0.9996508359909058]
# ch preds: ['alef', 'resh', 'tsadi-final']
# ch probs: [0.7528863549232483, 0.6443641185760498, 0.9932771325111389]
# Empty position: 2
# LSTM:  tsadi-final 0.9932771325111389
# CNN:  nun-final 0.5376762
# Final output: ['alef', 'resh', 'tsadi-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9997346
# Best character: resh
# Component:
# Recognizing the following character:
# Best score: 0.6262192
# Best character: het
# Component:
# Recognizing the following character:
# Best score: 0.9999925
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.9987464
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.6627665
# Best character: samekh
# Predicted sequence: ['resh', 'het', 'nun-final', 'kaf', 'samekh'] [0.9997346, 0.6262192, 0.9999925, 0.9987464, 0.6627665]
# -----LSTM:-------
# N chars: 5
# orig shape: (70, 172)
# Idx: [ 3  5 13 17 18]
# Idx: [17]
# Idx: [2]
# Idx: [0]
# Idx: [2]
# Idx: [2]
# Word preds: ['dalet', 'he', 'nun-medial', 'resh', 'samekh']
# Word probs: [0.06657835841178894, 0.07422114908695221, 0.25347617268562317, 0.8462324738502502, 0.9597026109695435]
# ch preds: ['resh', 'bet', 'alef', 'bet', 'bet']
# ch probs: [0.7173362970352173, 0.6532250046730042, 0.825191855430603, 0.733780562877655, 0.739658534526825]
# Empty position: 1
# LSTM:  bet 0.6532250046730042
# CNN:  het 0.6262192
# Empty position: 2
# LSTM:  alef 0.825191855430603
# CNN:  nun-final 0
# Empty position: 3
# LSTM:  bet 0.733780562877655
# CNN:  kaf 0.9987464
# Empty position: 4
# LSTM:  bet 0.739658534526825
# CNN:  samekh 0.6627665
# Final output: ['resh', 'bet', 'alef', 'kaf', 'bet']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.65370965
# Best character: tsadi-medial
# Component:
# Recognizing the following character:
# Best score: 0.69921684
# Best character: bet
# Predicted sequence: ['tsadi-medial', 'bet'] [0.65370965, 0.69921684]
# -----LSTM:-------
# N chars: 2
# orig shape: (53, 53)
# Idx: [ 9 10]
# Idx: [21]
# Idx: [18]
# Word preds: ['lamed', 'mem']
# Word probs: [0.06093982607126236, 0.6404078006744385]
# ch preds: ['tet', 'samekh']
# ch probs: [0.08220960944890976, 0.10931621491909027]
# Empty position: 0
# LSTM:  tet 0.08220960944890976
# CNN:  tsadi-medial 0
# Empty position: 1
# LSTM:  samekh 0.10931621491909027
# CNN:  bet 0.69921684
# Final output: ['tet', 'bet']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9877422
# Best character: nun-final
# Predicted sequence: ['nun-final'] [0.9877422]
# -----LSTM:-------
# N chars: 1
# orig shape: (54, 43)
# Idx: [4]
# Idx: [2]
# Word preds: ['gimel']
# Word probs: [0.5483927130699158]
# ch preds: ['bet']
# ch probs: [0.9966596364974976]
# Empty position: 0
# LSTM:  bet 0.9966596364974976
# CNN:  nun-final 0.9877422
# Final output: ['bet']
# test7
# ch: bet
# code: 1489
# chr: ב
# ch: lamed
# code: 1500
# chr: ל
# ch: waw
# code: 1493
# chr: ו
# ch: shin
# code: 1513
# chr: ש
# ch: waw
# code: 1493
# chr: ו
# ch: bet
# code: 1489
# chr: ב
# ch: he
# code: 1492
# chr: ה
# ch: alef
# code: 1488
# chr: א
# ch: resh
# code: 1512
# chr: ר
# ch: tsadi-final
# code: 1509
# chr: ץ
# ch: resh
# code: 1512
# chr: ר
# ch: bet
# code: 1489
# chr: ב
# ch: alef
# code: 1488
# chr: א
# ch: kaf
# code: 1499
# chr: כ
# ch: bet
# code: 1489
# chr: ב
# ch: tet
# code: 1496
# chr: ט
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9997123
# Best character: nun-final
# Component:
# (50, 43)
# Recognizing the following character:
# Best score: 0.97365487
# Best character: he
# (50, 35)
# Recognizing the following character:
# Best score: 0.6890542
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.99985445
# Best character: yod
# Predicted sequence: ['nun-final', 'nun-medial', 'he', 'yod'] [0.9997123, 0.6890542, 0.97365487, 0.99985445]
# -----LSTM:-------
# N chars: 4
# orig shape: (56, 141)
# Idx: [ 0  6 17 18]
# Idx: [24]
# Idx: [2]
# Idx: [5]
# Idx: [17]
# Word preds: ['alef', 'het', 'resh', 'samekh']
# Word probs: [0.234551802277565, 0.40638574957847595, 0.5743022561073303, 0.7034103870391846]
# ch preds: ['waw', 'bet', 'he', 'resh']
# ch probs: [0.25284093618392944, 0.7322825193405151, 0.5532044172286987, 0.462109237909317]
# Empty position: 0
# LSTM:  waw 0.25284093618392944
# CNN:  nun-final 0
# Empty position: 1
# LSTM:  bet 0.7322825193405151
# CNN:  nun-medial 0.6890542
# Empty position: 2
# LSTM:  he 0.5532044172286987
# CNN:  he 0.97365487
# Empty position: 3
# LSTM:  resh 0.462109237909317
# CNN:  yod 0.99985445
# Final output: ['waw', 'bet', 'he', 'yod']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 1.0
# Best character: nun-final
# Component:
# (52, 38)
# Recognizing the following character:
# Best score: 0.99270296
# Best character: he
# (52, 45)
# Recognizing the following character:
# Best score: 0.99710697
# Best character: ayin
# Predicted sequence: ['nun-final', 'ayin', 'he'] [1.0, 0.99710697, 0.99270296]
# -----LSTM:-------
# N chars: 3
# orig shape: (58, 115)
# Idx: [3 5 6]
# Idx: [12]
# Idx: [1]
# Idx: [5]
# Word preds: ['dalet', 'he', 'het']
# Word probs: [0.22897456586360931, 0.6436047554016113, 0.7357423305511475]
# ch preds: ['nun-final', 'ayin', 'he']
# ch probs: [0, 0.9866811037063599, 0.6364436745643616]
# Empty position: 1
# LSTM:  ayin 0.9866811037063599
# CNN:  ayin 0.99710697
# Final output: ['dalet', 'ayin', 'he']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.6233517
# Best character: mem
# Component:
# Recognizing the following character:
# Best score: 1.0
# Best character: tet
# Component:
# Recognizing the following character:
# Best score: 0.8839164
# Best character: he
# Predicted sequence: ['mem', 'tet', 'he'] [0.6233517, 1.0, 0.8839164]
# -----LSTM:-------
# N chars: 3
# orig shape: (56, 140)
# Idx: [ 5  6 21]
# Idx: [6]
# Idx: [21]
# Idx: [5]
# Word preds: ['he', 'het', 'tet']
# Word probs: [0.9598896503448486, 0.9653764963150024, 0.9957725405693054]
# ch preds: ['het', 'tet', 'he']
# ch probs: [0.920758068561554, 0.9179031848907471, 0.9992539286613464]
# Final output: ['het', 'tet', 'he']
# Recognizing the following word:
# -----CNN:-------
# Component:
# (44, 29)
# Recognizing the following character:
# Best score: 0.9785851
# Best character: dalet
# (44, 39)
# Recognizing the following character:
# Best score: 0.99998343
# Best character: alef
# Component:
# Recognizing the following character:
# Best score: 0.83194613
# Best character: tsadi-medial
# Predicted sequence: ['alef', 'dalet', 'tsadi-medial'] [0.99998343, 0.9785851, 0.83194613]
# -----LSTM:-------
# N chars: 3
# orig shape: (51, 123)
# Idx: [ 0 17 19]
# Idx: [0]
# Idx: [17]
# Idx: [1]
# Word preds: ['alef', 'resh', 'shin']
# Word probs: [0.39374515414237976, 0.4928690791130066, 0.6062771081924438]
# ch preds: ['alef', 'resh', 'ayin']
# ch probs: [0.9998791217803955, 0.5437875986099243, 0.7499783039093018]
# Final output: ['alef', 'resh', 'ayin']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.999979
# Best character: nun-final
# Component:
# Recognizing the following character:
# Best score: 0.9999862
# Best character: shin
# Component:
# Recognizing the following character:
# Best score: 0.6149024
# Best character: nun-final
# Predicted sequence: ['nun-final', 'shin', 'nun-final'] [0.999979, 0.9999862, 0.6149024]
# -----LSTM:-------
# N chars: 3
# orig shape: (48, 131)
# Idx: [ 1 17 19]
# Idx: [24]
# Idx: [19]
# Idx: [1]
# Word preds: ['ayin', 'resh', 'shin']
# Word probs: [0.9818938970565796, 0.9944625496864319, 0.9997010827064514]
# ch preds: ['waw', 'shin', 'ayin']
# ch probs: [0.7463949918746948, 0.9999059438705444, 0.9129174947738647]
# Empty position: 0
# LSTM:  waw 0.7463949918746948
# CNN:  nun-final 0
# Final output: ['waw', 'shin', 'ayin']
# test7
# ch: waw
# code: 1493
# chr: ו
# ch: bet
# code: 1489
# chr: ב
# ch: he
# code: 1492
# chr: ה
# ch: yod
# code: 1497
# chr: י
# ch: dalet
# code: 1491
# chr: ד
# ch: ayin
# code: 1506
# chr: ע
# ch: he
# code: 1492
# chr: ה
# ch: het
# code: 1495
# chr: ח
# ch: tet
# code: 1496
# chr: ט
# ch: he
# code: 1492
# chr: ה
# ch: alef
# code: 1488
# chr: א
# ch: resh
# code: 1512
# chr: ר
# ch: ayin
# code: 1506
# chr: ע
# ch: waw
# code: 1493
# chr: ו
# ch: shin
# code: 1513
# chr: ש
# ch: ayin
# code: 1506
# chr: ע
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.6909636
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.9624164
# Best character: yod
# Component:
# Recognizing the following character:
# Best score: 0.9977531
# Best character: bet
# Predicted sequence: ['nun-medial', 'yod', 'bet'] [0.6909636, 0.9624164, 0.9977531]
# -----LSTM:-------
# N chars: 3
# orig shape: (94, 52)
# Idx: [ 7 11 13]
# Idx: [2]
# Idx: [25]
# Idx: [7]
# Word preds: ['kaf', 'mem-medial', 'nun-medial']
# Word probs: [0.4724797010421753, 0.5015351176261902, 0.5937507748603821]
# ch preds: ['bet', 'yod', 'kaf']
# ch probs: [0.6958827972412109, 0.4572254717350006, 0.6572283506393433]
# Empty position: 1
# LSTM:  yod 0.4572254717350006
# CNN:  yod 0.9624164
# Final output: ['bet', 'yod', 'kaf']
# Recognizing the following word:
# -----CNN:-------
# Predicted sequence: [] []
# -----LSTM:-------
# N chars: 0
# Recognizing the following word:
# -----CNN:-------
# Component:
# (68, 29)
# Recognizing the following character:
# Best score: 0.9981818
# Best character: resh
# (68, 29)
# Recognizing the following character:
# Best score: 0.99993384
# Best character: alef
# Component:
# Recognizing the following character:
# Best score: 0.8188448
# Best character: tsadi-final
# Predicted sequence: ['alef', 'resh', 'tsadi-final'] [0.99993384, 0.9981818, 0.8188448]
# -----LSTM:-------
# N chars: 3
# orig shape: (74, 113)
# Idx: [ 0 17 22]
# Idx: [24]
# Idx: [17]
# Idx: [22]
# Word preds: ['alef', 'resh', 'tsadi-final']
# Word probs: [0.9987003803253174, 0.999927282333374, 0.9999792575836182]
# ch preds: ['waw', 'resh', 'tsadi-final']
# ch probs: [0.2951916456222534, 0.6662999987602234, 0.9990602135658264]
# Empty position: 0
# LSTM:  waw 0.2951916456222534
# CNN:  alef 0.99993384
# Final output: ['alef', 'resh', 'tsadi-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.544705
# Best character: nun-medial
# Component:
# Recognizing the following character:
# Best score: 0.6823327
# Best character: kaf
# Predicted sequence: ['nun-medial', 'kaf'] [0.544705, 0.6823327]
# -----LSTM:-------
# N chars: 2
# orig shape: (72, 69)
# Idx: [ 2 11]
# Idx: [2]
# Idx: [12]
# Word preds: ['bet', 'mem-medial']
# Word probs: [0.054700810462236404, 0.511079728603363]
# ch preds: ['bet', 'nun-final']
# ch probs: [0.8683007955551147, 0.6203468441963196]
# Empty position: 1
# LSTM:  nun-final 0.6203468441963196
# CNN:  kaf 0.6823327
# Final output: ['bet', 'kaf']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9074081
# Best character: kaf-final
# Component:
# Recognizing the following character:
# Best score: 0.4268195
# Best character: bet
# Component:
# Recognizing the following character:
# Best score: 0.9940758
# Best character: bet
# Component:
# (48, 12)
# Recognizing the following character:
# Best score: 0.9944542
# Best character: nun-final
# (48, 21)
# Recognizing the following character:
# Best score: 0.51084036
# Best character: bet
# (48, 21)
# Recognizing the following character:
# Best score: 0.9693496
# Best character: nun-final
# Predicted sequence: ['kaf-final', 'bet', 'bet', 'nun-final', 'bet', 'nun-final'] [0.9074081, 0.4268195, 0.9940758, 0.9693496, 0.51084036, 0.9944542]
# -----LSTM:-------
# N chars: 6
# orig shape: (53, 128)
# Idx: [ 9 10 16 18 19 23]
# Idx: [16]
# Idx: [2]
# Idx: [2]
# Idx: [2]
# Idx: [14]
# Idx: [20]
# Word preds: ['lamed', 'mem', 'qof', 'samekh', 'shin', 'tsadi-medial']
# Word probs: [0.00014290241233538836, 0.0002014458441408351, 0.00021644124353770167, 0.0002883858687710017, 0.8850389719009399, 0.9991999268531799]
# ch preds: ['qof', 'bet', 'bet', 'bet', 'pe', 'taw']
# ch probs: [0.7537977695465088, 0.9782034158706665, 0.3882385492324829, 0.7422299981117249, 0.2651638388633728, 0.10589437186717987]
# Empty position: 1
# LSTM:  bet 0.9782034158706665
# CNN:  bet 0.4268195
# Empty position: 2
# LSTM:  bet 0.3882385492324829
# CNN:  bet 0.9940758
# Empty position: 3
# LSTM:  bet 0.7422299981117249
# CNN:  nun-final 0
# Empty position: 4
# LSTM:  pe 0.2651638388633728
# CNN:  bet 0.51084036
# Empty position: 5
# LSTM:  taw 0.10589437186717987
# CNN:  nun-final 0.9944542
# Final output: ['qof', 'bet', 'bet', 'bet', 'bet', 'nun-final']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.87257546
# Best character: resh
# Predicted sequence: ['resh'] [0.87257546]
# -----LSTM:-------
# N chars: 1
# orig shape: (45, 82)
# Idx: [17]
# Idx: [17]
# Word preds: ['resh']
# Word probs: [0.9925417900085449]
# ch preds: ['resh']
# ch probs: [0.7348389029502869]
# Final output: ['resh']
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.69719505
# Best character: nun-final
# Component:
# (44, 43)
# Recognizing the following character:
# Best score: 0.5600935
# Best character: tsadi-medial
# (44, 35)
# Recognizing the following character:
# Best score: 0.5927277
# Best character: bet
# Predicted sequence: ['nun-final', 'bet', 'tsadi-medial'] [0.69719505, 0.5927277, 0.5600935]
# -----LSTM:-------
# N chars: 3
# orig shape: (50, 104)
# Idx: [ 0 20 25]
# Idx: [2]
# Idx: [7]
# Idx: [20]
# Word preds: ['alef', 'taw', 'yod']
# Word probs: [0.005265515763312578, 0.8644695281982422, 0.9997106194496155]
# ch preds: ['bet', 'kaf', 'taw']
# ch probs: [0.08003267645835876, 0.5943061709403992, 0.9998996257781982]
# Empty position: 0
# LSTM:  bet 0.08003267645835876
# CNN:  nun-final 0
# Empty position: 1
# LSTM:  kaf 0.5943061709403992
# CNN:  bet 0.5927277
# Final output: ['bet', 'kaf', 'taw']
# test7
# ch: bet
# code: 1489
# chr: ב
# ch: yod
# code: 1497
# chr: י
# ch: kaf
# code: 1499
# chr: כ
# ch: alef
# code: 1488
# chr: א
# ch: resh
# code: 1512
# chr: ר
# ch: tsadi-final
# code: 1509
# chr: ץ
# ch: bet
# code: 1489
# chr: ב
# ch: kaf
# code: 1499
# chr: כ
# ch: qof
# code: 1511
# chr: ק
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: bet
# code: 1489
# chr: ב
# ch: nun-final
# code: 1503
# chr: ן
# ch: resh
# code: 1512
# chr: ר
# ch: bet
# code: 1489
# chr: ב
# ch: kaf
# code: 1499
# chr: כ
# ch: taw
# code: 1514
# chr: ת
# Recognizing the following word:
# -----CNN:-------
# Component:
# Recognizing the following character:
# Best score: 0.9999696
# Best character: nun-final
# Component:
# (52, 22)
# Recognizing the following character:
# Best score: 0.9600985
# Best character: nun-medial
# (52, 39)
# Recognizing the following character:
# Best score: 0.49989215
# Best character: kaf
# Component:
# Recognizing the following character:
# Best score: 0.941154
# Best character: pe
# Predicted sequence: ['nun-final', 'kaf', 'nun-medial', 'pe'] [0.9999696, 0.49989215, 0.9600985, 0.941154]
# -----LSTM:-------
# N chars: 4
# orig shape: (102, 119)
# Idx: [ 0 13 20 21]
# Idx: [24]
# Idx: [11]
# Idx: [17]
# Idx: [17]
# Word preds: ['alef', 'nun-medial', 'taw', 'tet']
# Word probs: [0.170781210064888, 0.17160354554653168, 0.2741876244544983, 0.3091091513633728]
# ch preds: ['waw', 'mem-medial', 'resh', 'resh']
# ch probs: [0.9806727766990662, 0.759675920009613, 0.428550124168396, 0.8770347833633423]
# Empty position: 0
# LSTM:  waw 0.9806727766990662
# CNN:  nun-final 0
# Empty position: 1
# LSTM:  mem-medial 0.759675920009613
# CNN:  kaf 0.49989215
# Empty position: 2
# LSTM:  resh 0.428550124168396
# CNN:  nun-medial 0.9600985
# Empty position: 3
# LSTM:  resh 0.8770347833633423
# CNN:  pe 0.941154
# Final output: ['waw', 'mem-medial', 'nun-medial', 'pe']
# Recognizing the following word:
# -----CNN:-------
# Component:
# (50, 28)
# Recognizing the following character:
# Best score: 0.92145205
# Best character: resh
# (50, 33)
# Recognizing the following character:
# Best score: 0.9944382
# Best character: bet
# Component:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f88b80d4584b> in <module>()
# ----> 1 recognize_handwriting(image, path, plot = True)
#
# D:\AI\BlockD\handwritingRecognition\hwr\Preprocessing\recognize_handwriting.py in recognize_handwriting(image, path, plot)
#     490             #characters = extract_characters(cv2.morphologyEx(word, cv2.MORPH_CLOSE, kernel), avg_width)
#     491             print("-----CNN:-------")
# --> 492             chars, sequence, confidences = recognize_word(word, avg_width,  all_prob, first_chars_prob, plot)
#     493             print("-----LSTM:-------")
#     494             final_sequence = recognize_word_lstm(word, chars, sequence, confidences, model, avg_width, plot)
#
# D:\AI\BlockD\handwritingRecognition\hwr\Preprocessing\recognize_word_window.py in recognize_word(word, avg_width, trans_matrix, start_vector, plot)
#     134             plt.figure(figsize = (500,4))
#     135             plt.imshow(ch, cmap='gray', aspect = 1)
# --> 136             plt.show()
#     137
#     138             # components that are too big need to be processed further, as they probably consist
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     249     """
#     250     global _show
# --> 251     return _show(*args, **kw)
#     252
#     253
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      34     try:
#      35         for figure_manager in Gcf.get_all_fig_managers():
# ---> 36             display(figure_manager.canvas.figure)
#      37     finally:
#      38         show._to_draw = []
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     295             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     296         else:
# --> 297             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     298             if not format_dict:
#     299                 # nothing to display (e.g. _ipython_display_ took over)
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# <decorator-gen-9> in __call__(self, obj)
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     236
#     237     if 'png' in formats:
# --> 238         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     239     if 'retina' in formats or 'png2x' in formats:
#     240         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     120
#     121     bytes_io = BytesIO()
# --> 122     fig.canvas.print_figure(bytes_io, **kw)
#     123     data = bytes_io.getvalue()
#     124     if fmt == 'svg':
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, **kwargs)
#    2206                     orientation=orientation,
#    2207                     dryrun=True,
# -> 2208                     **kwargs)
#    2209                 renderer = self.figure._cachedRenderer
#    2210                 bbox_inches = self.figure.get_tightbbox(renderer)
#
# c:\users\paul\appdata\local\programs\python\python36\lib\site-packages\matplotlib\backends\backend_agg.py in print_png(self, filename_or_obj, *args, **kwargs)
#     524         try:
#     525             _png.write_png(renderer._renderer, filename_or_obj,
# --> 526                            self.figure.dpi, metadata=metadata)
#     527         finally:
#     528             if close:
#
# KeyboardInterrupt:
